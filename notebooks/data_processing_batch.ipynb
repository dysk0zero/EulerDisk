# %%
import os

import numpy as np
import euler_disk as ed
import matplotlib.pyplot as plt

# %% [markdown]
# # Notebook Data Analysis of Euler Disk
# Note: This is the batch version of the data analysis notebook, intended to perform analysis of all of the experimental data in every run.

# %% [markdown]
# ## Input Data Folder
# Under this folder are all the wav files.

# %%
input_dir = "../data/wav/"
data_files = sorted([file for file in os.listdir(input_dir) if file.endswith(".wav")])

# %% [markdown]
# ## Data Processing
